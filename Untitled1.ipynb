# %%
import numpy as np
from skimage import exposure
from skimage.io import imread
from skimage.color import rgb2lab, lab2rgb, rgb2gray
from skimage.transform import radon, iradon
import matplotlib.pylab as plt
import cv2
import math
from PIL import Image
from datetime import datetime, date
import ipywidgets as widgets
from tomograf import Tomograf, write_dicom
from sklearn.preprocessing import MinMaxScaler

# %%
#sciezka do pliku/rozpietosc/iloscEmiterow/krok w stopniach/z filtrem lub bez
#t1 = Tomograf('img/Shepp_logan.jpg',180,300,1)
#t1 = Tomograf('img/Kropka.jpg',90,180,2, True)
#t1 = Tomograf('img/CT_ScoutView-large.jpg',90,180,2)
#t1 = Tomograf('dicom/Kolo.dcm',90,100,2)
plt.figure(figsize=(10,10))
plt.imshow(t1.img, cmap='gray'), plt.axis('off'),plt.title('original img', size=20)
# Out:
# (<matplotlib.image.AxesImage at 0x227fa2745e0>,
#  (-0.5, 1299.5, 1512.5, -0.5),
#  Text(0.5, 1.0, 'original img'))

# %%
t1.wyznaczPozycjeEmiterow()

# %%
#False - bez filtra, True - z filtrem
t1.wyswietlSinogram(True)
t1.wyswietlSinogram(False)

# %%
#wyswietlenie maski
plt.plot(t1.kernel)

# %%
suwak = widgets.IntSlider(
    value=t1.iloscSkanow/2,
    min=1,
    max=t1.iloscSkanow,
    step=1,
    description='Ilosc iteracji:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
display(suwak)
# Out:
# IntSlider(value=45, continuous_update=False, description='Ilosc iteracji:', max=90, min=1)

# %%
#False - bez filtra, True - z filtrem
t1.imgReconstruction(False,suwak.value)
#t1.imgReconstruction(False)

# %%
#t1.imgReconstruction(True,suwak.value)
t1.imgReconstruction(True)

# %%
#dla filtra (20,99)/ bez filtra(1,99)
lo, hi = np.percentile(t1.reconstructed,(20,99))
temp = exposure.rescale_intensity(t1.reconstructed, in_range=(lo,hi))
plt.figure(figsize=(10,10))
plt.imshow(temp,cmap='gray'), plt.axis('off')
# Out:
# (<matplotlib.image.AxesImage at 0x227819d0640>, (-0.5, 1299.5, 1512.5, -0.5))

# %%
write_dicom('finalImage.dcm', t1.reconstructed, dict(
    PatientName='Bartosz Kosmider',
    PatientID='142430',
    ImageComments='komentarz',
    StudyDate='20210925',
))

# %%
krokAlfa = 2
Tomograf('img/Kropka.jpg',90,300,krokAlfa, True, None, False)

# %%
iteracje = np.arange(0,180/krokAlfa, krokAlfa*4)
for i in iteracje:
    Tomograf('img/Kropka.jpg',90,300, krokAlfa, True, int(i), True)
